# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import calendar

# %%
data = pd.read_csv(r"C:\Users\hp\Desktop\full stack\Uber Drives - .csv")
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data=data.drop(1155, axis=0)
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
data['START_DATE*'] = pd.to_datetime(data['START_DATE*'], format="%m/%d/%Y %H:%M")
data['END_DATE*'] = pd.to_datetime(data['END_DATE*'], format="%m/%d/%Y %H:%M")

# %%
data.isnull().any()
# Out:
# START_DATE*    False
# END_DATE*      False
# CATEGORY*      False
# START*         False
# STOP*          False
# MILES*         False
# PURPOSE*        True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
hour=[]
day=[]
dayofweek=[]
month=[]
weekday=[]
for x in data['START_DATE*']:
    hour.append(x.hour)
    day.append(x.day)
    dayofweek.append(x.dayofweek)
    month.append(x.month)
    weekday.append(calendar.day_name[dayofweek[-1]])
data['HOUR']=hour
data['DAY']=day
data['DAY_OF_WEEK']=dayofweek
data['MONTH']=month
data['WEEKDAY']=weekday

# %%
data.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*  HOUR  DAY  DAY_OF_WEEK  MONTH  \
# 0      Fort Pierce     5.1   Meal/Entertain    21    1            4      1
# 1      Fort Pierce     5.0              NaN     1    2            5      1
# 2      Fort Pierce     4.8  Errand/Supplies    20    2            5      1
# 3      Fort Pierce     4.7          Meeting    17    5            1      1
# 4  West Palm Beach    63.7   Customer Visit    14    6            2      1
#
#      WEEKDAY
# 0     Friday
# 1   Saturday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday

# %% [markdown]
# CHECK FOR THE CATEGORIES WE HAVE

# %%
data['CATEGORY*'].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
sns.countplot(x='CATEGORY*',data=data)
# Out:
# <AxesSubplot:xlabel='CATEGORY*', ylabel='count'>

# %%
data['START*'].value_counts()
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: START*, Length: 177, dtype: int64

# %% [markdown]
# HOW LONG PEOPLE CARRY UBER

# %%
data['MILES*'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# TIME PEOPLE USE UBER MOSTLY

# %%
hours = data['START_DATE*'].dt.hour.value_counts()
hours.plot(kind='bar',color='orange',figsize=(10,5))
plt.xlabel('Hours')
plt.ylabel('Frequency')
plt.title('Number of trips Vs hours')
# Out:
# Text(0.5, 1.0, 'Number of trips Vs hours')

# %% [markdown]
# PURPOSE OF MOST TRIPS TAKEN WITH UBER

# %%
data['PURPOSE*'].value_counts().plot(kind='bar',figsize=(10,5),color='brown')
# Out:
# <AxesSubplot:>

# %% [markdown]
# DAY WITH HIGHEST TRIP

# %%
data['WEEKDAY'].value_counts().plot(kind='bar',figsize=(10,5),color='orangered')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Number of trips per day

# %%
data['DAY'].value_counts().plot(kind='bar',figsize=(10,5),color='green')
# Out:
# <AxesSubplot:>

# %% [markdown]
# TRIPS PER MONTH

# %%
data['MONTH'].value_counts().plot(kind='bar',figsize=(10,5),color='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# MOST TRIP START POINT

# %%
data['START*'].value_counts().plot(kind='bar',figsize=(25,10),color='blue')
# Out:
# <AxesSubplot:>
